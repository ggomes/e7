# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center>Discussion week 6<br></center></h2>
#
# <h1><center>Using files and modules in a simulation<br></center></h2>
#
# ---
