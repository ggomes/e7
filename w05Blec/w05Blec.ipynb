# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center> Lecture w05-B <br></center></h2>
# <h2><center> Strings</h2>
#
# ---

# %% [markdown]
# ### A string is a **sequence**
#
# You can
# + index a string with integer and slices,
# + get length with **len**,
# + test membership with **in**.

# %% [markdown]
# ### String addition

# %% [markdown]
# ### String * integer

# %% [markdown]
# ### Search a string

# %%
url = 'https://www.imdb.com/title/tt0887883/'
filename = 'myhomevideo.mp4'
line = '\tAppearances can be deceptive.\n'
email = 'ChadFeldheimer@aol.com'
values = 'tt0887883,25.3,90'

# %% [markdown]
# ### Modify a string

# %% [markdown]
# ### Split a string

# %% [markdown]
# ### Join strings with a delimiter

# %% [markdown]
# ### Example #1: Construct this string using the variables below
#
# ```python
# "Bach died in 1750 at the age of 65."

# %%
name = 'Johann Sebastian Bach'
birth_year = 1685
death_year = 1750

# %% [markdown]
# ### Example #2: Construct this string using the variables below
#
# ```python
# "The area of the circle is 3.17"

# %%
import numpy as np
radius = 3.2
area = np.pi*radius**2
'The area of the circle is '

# %% [markdown]
# ## Formatting with f-strings

# %%
I = 234095823     # an integer
F = 9024.1382     # a float

# %% [markdown]
# ### Example formatting a table
#
# <img src="table.png" width="300" />

# %%
EGU = 7_303_480
NMM = 3_316_142

# %% [markdown]
# ### Unicode emojis

# %%
print("\U0001F680")  # 🚀
print("\U0001F60E")  # 😎
print("\U0001F984")  # 🦄
print("\U0001F525")  # 🔥
print("\U0001F47D")  # 👽
