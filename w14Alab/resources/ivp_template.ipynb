# %%
def ivp_solver(f,ts,h,y0,shat_estimator):
    
    # Create the time grid using get_time_grid
    ...

    # Allocate the yhat array
    ...

    # Initialize: set the first value of yhat to y0
    ...

    # Run the iteration forward over all time.
    # At each step: 
    # 1. use shat_estimator to compute shat
    # 2. use shat to compute the next value of yhat 
    ...

    return tvec, yhat
