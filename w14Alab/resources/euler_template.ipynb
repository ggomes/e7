# %%
def euler_solver(ts,h,T0,Ta):

    # Create the time grid using get_time_grid
    ...

    # Initialze That to an empty 1D NumPy array with K elements
    ...

    # Set the zeroth element of That to the initial condition
    ...

    # Iterate through the rest of That, setting values according to Euler's method
    # Use the cooling_law function for the system equation f.
    ...

    return tvec, That
