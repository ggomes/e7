# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center> Lecture w03-B <br></center></h2>
# <h2><center>"for" loops</h2>
#
# ---

# %% [markdown]
# # Simple ''for'' loop

# %%
alist  = [ 1 , 'hello' , None ]
aset   = { 1 , 'hello' , None }
astr   = 'abcdefg'
adict  = {  'zero'  : 'cero' , 
            'apple' : 'manzana' , 
            'house' : 'casa' } 
...

# %% [markdown]
# # Example use of a ''for'' loop
#
# Compute the areas of circles whose radii are given in `radii`.
#
# Store the result in a list called `areas`.

# %%
radii = (1.4, 5.2, 9.5, 12.5)

...

# %% [markdown]
# # Three ways of iterating through a dictionary

# %%
country_population = {
    'India' :         1_428_627_663,
    'China' :         1_425_671_352,
    'United States' :   339_996_563,
    'Indonesia' :       277_534_122,
    'Pakistan' :        240_485_658
}

# %% [markdown]
# ## 1) Iterating through keys

# %% [markdown]
# ## 2) Iterating through values with `.values()`

# %% [markdown]
# ## 3) Iterating through key-value pairs with `.items()`

# %% [markdown]
# # Example: Building a small English-to-Spanish dictionary
#
# You have a list of words in English and a list of their corresponding words in Spanish.
#
# Build a dictionary with the English words as keys and the Spanish words as values.

# %%
E = ['zero','one','two','three']
S = ['cero','uno','dos','tres']

...

# %% [markdown]
# # range

# %% [markdown]
# # enumerate

# %% [markdown]
# # zip
