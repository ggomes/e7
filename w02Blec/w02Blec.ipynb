# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center> Lecture w02-B <br></center></h2>
# <h2><center> *if* statements and *while* loops</h2>
#
# ---

# %% [markdown]
# # Speeding ticket
#
# ### Version 1

# %%
speed_limit = 65
speed = 68
has_license = False

if speed>speed_limit:
    if has_license:
        print("You get a ticket!")
    else:
        print("You are under arrest!")
else:
    if speed<0:
        print("I have a few questions for you...")
    else:
        print("Have a nice day!")
# Out:
# You are under arrest!

# %% [markdown]
# ### Version 2

# %%
speed_limit = 65
speed = 68
has_license = False

if speed>speed_limit:
    if has_license:
        print("You get a ticket!")
    else:
        print("You are under arrest!")
elif speed<0:
    print("I have a few questions for you...")
else:
    print("Have a nice day!")
# Out:
# You are under arrest!

# %% [markdown]
# ### Version 3

# %%
speed_limit = 65
speed = 68
has_license = False

if speed<speed_limit:
    if speed<0:
        print("I have a few questions for you...")
    else:
        print("Have a nice day!")
elif has_license:
    print("You get a ticket!")
else:
    print("You are under arrest!")
# Out:
# You are under arrest!

# %% [markdown]
# # Number adding program

# %% [markdown]
# ### Version 1

# %%
print("Welcome to the number adding program!")
total = 0
add_string = input("Enter a number to add (or type 'stop'): ") 
while add_string!="stop":
    add = float(add_string)
    total += add
    print("Total: ",total)
    add_string = input("Enter a number to add (or type 'stop'): ")
# Out:
# Welcome to the number adding program!
# Total:  1.0
# Total:  4.0
# Total:  9.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 5
#       3 add_string = input("Enter a number to add (or type 'stop'): ")
#       4 while add_string!="stop":
# ----> 5     add = float(add_string)
#       6     total = total + add
#       7     print("Total: ",total)
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# ### Version 2

# %%
print("Welcome to the number adding program!")
total = 0
while True:
    add_string = input("Enter a number to add (or type 'stop'): ") 
    if add_string=='stop':
        break
    add = float(add_string)
    total += add
    print("Total: ",total)
