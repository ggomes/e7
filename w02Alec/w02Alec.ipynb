# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center> Lecture w02-A <br></center></h2>
# <h2><center> Scalar data types and Operator precedence</h2>
#
# ---

# %% [markdown]
# ## Scalar types
#
# Create an integer and a float and check their `type`

# %% [markdown]
# ## Scalar arithmetic
#
# <center><img width=250 src="resources/scalar_arithmetic.png" /></center>
#
# Try it out:

# %% [markdown]
# ## The **math** package

# %%
import math

# %% [markdown]
# ## Complex numbers and the **cmath** package
#
# <center><img width=400 src="resources/complex.png" /></center>

# %% [markdown]
# ## Parabolic motion
#
# <center><img width=400 src="resources/tennis_ball_formula.png" /></center>

# %%
g = 9.81        # [m/s2] acceleration of gravity in 
d = 10          # [m] distance to bounce 
theta0 = 45     # [degrees] initial angle``
h = 0.8         # [m] initial height

# %% [markdown]
# ## Booleans
