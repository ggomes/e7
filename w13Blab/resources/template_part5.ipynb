# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center>Lab session #13-B <br></center></h2>
#
# <h1><center>Template for part 5<br></center></h1>
#
# ---

# %%
def create_matrix_form():
    
    # initialize A and b
    A = ...
    b = ...

    # Loop through unmeasured nodes / rows of A 
    for i in range(len(nodes_unmeasured)):

        # Every row has a 1 in the i'th column
        ...

        # Get the set of neighbors for this node.
        ...

        # Iterate through the neighbors
        for ... :

            # If this neighbor is unmeasured, then it appears on the left-hand side of the equation (ie in A).
            # Put -1/len(neighbors) in the corresponding position of A (Hint: list.index)
            if ...:
                ...
            
            # If this neighbor is measured, then it appears on the right-hand side of the equation (ie in b).
            # Put the measured temperature divided by len(neighbors) in the corresponding position of b.
            if ...:
                ...

    return A, b
# END SOLUTION
