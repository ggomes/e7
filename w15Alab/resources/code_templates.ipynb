# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center>Lab session #15-A <br></center></h2>
#
# <h1><center>Function templates<br></center></h1>
#
# ---

# %%
import numpy as np

# %% [markdown]
# ## Part 2.1

# %%
def ball_flight_equation(t,z):

    # unpack z into variables px, py, vx, vy
    ...

    # define the velocity v in terms of vx and vy
    ...
    
    # define the constant K
    ...

    # code the state equation
    ...

    # return the derivatives in the correct order
    return ...

# %%
## Part 2.4

# %%
def success(px,py):

    # Find k, the index of the last point in the trajectory where the ball is above the rim.
    ...

    # compute xstar using the formula
    ...

    # success if and only if xstar is in the interval
    success = ...
    
    return success

# %%
## Part 2.6

# %%
tf = 2     # seconds
K = 100    # time steps
t_eval = np.linspace(0,tf,K)   # evaluation grid
N = 150    # random initial conditions
 
successes = ...    # boolean array of succes/no-success values
traj = ...         # empty array with shape (K,2,N)

# iterate through all initial conditions
for i in range(N):

    # initial condition
    px0 = ...
    py0 = ...
    theta0 = ...
    v0 = ...

    # compute initial vx and vy from v0 and theta0
    ...

    # call solve_ivp
    sol = solve_ivp( fun=...,     # the state equation
                    t_span=...,   # initial and final time
                    y0=...,       # initial state
                    t_eval=...)   # evaluation instants

    # Extract px and py from sol
    ...

    # Store px and py in traj
    ...

    # Evaluate success
    successes[i] = ...
