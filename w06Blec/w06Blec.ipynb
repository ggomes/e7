# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center> Lecture w06-B <br></center></h2>
# <h2><center> Modules</h2>
#
# ---

# %% [markdown]
# ### Importing with `from` and `as`

# %%
from moduleB import sayHi as sayHiA
from moduleA import sayHi as sayHiB

sayHiA()
sayHiB()
