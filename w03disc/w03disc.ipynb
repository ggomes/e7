# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center>Discussion week 3 <br></center></h2>
#
# <h1><center>Comprehensions<br></center></h2>
#
# ---

# %% [markdown]
# ## Part 1. Comprehensions with number sequences
#
# #### 1.1) Construct a list of powers of 2 from 0 to 4 inclusive

# %% [markdown]
# #### 1.2) How many numbers in the list below are multiples of 3?

# %%
A = [1,2,3,4,5,6,7,8,9,20,12,14,15,17,18]

# %% [markdown]
# #### 1.3) Find the smallest positive integer which has no multiple in `A`.
#
# Can this be done with a one-line comprehension?

# %% [markdown]
# # Part 2. Text analysis

# %%
paragraph = '''
The snowy plover (Anarhynchus nivosus) is a small shorebird found in much of the 
Americas on both coasts and inland  Inland populations are migratory  whereas 
some coastal birds are resident  This plover is brown above and white below  
with a white band on the neck  a slender black bill  and gray to black legs  
Breeding males have black patches behind the eye and on the neck  The typical 
call is a repeated "tu-wheet"  The bird inhabits open areas with sparse 
vegetation  like sandy beaches and shores of salt or soda lakes  where it 
feeds on invertebrates  such as crustaceans  worms  beetles  and flies  Males 
excavate multiple nest scrapes that are advertised to females  who may be 
polygamous  The species is listed as near threatened by the IUCN  The main 
threats are habitat destruction due to invasive beach grasses  urban development  
and disturbance due to recreational uses of beaches  While conservation measures 
have been successful locally  the global population is thought to be in decline 
'''
words = paragraph.lower().split()

# %% [markdown]
# #### 2.1) How many words does the paragraph contain?

# %% [markdown]
# #### 2.2) How many *unique* words does the paragraph contain?

# %% [markdown]
# #### 2.3) Which four-letter words can be found in the paragraph?

# %% [markdown]
# #### 2.4) What are the indexes all of the four-letter words in the paragraph?

# %% [markdown]
# #### 2.5) What is the total length of the words in the paragraph that are not four letter words? (count repetitions)

# %% [markdown]
# #### 2.6) Count the number of times that each 4-letter word appears in the paragraph.

# %% [markdown]
# # Part 3.
#
# An event planner must choose the location for their event from among 4 lots. The dimensions (width and depth in feet) of the four lots are provided as a set of tuples. The main criteria is that the lot should measure at least 70,000 sqft. Which of the lots are suitable?

# %%
lot_dimensions = {
    (120,530),
    (450,150),
    (120,500),
    (540,140),
    (800,100)
}

# %% [markdown]
# #### 3.1) Solve it with a loop.

# %% [markdown]
# #### 3.2) Solve it with a comprehension.

# %% [markdown]
# #### In addition to area>70,000 sqft, the ratio of perimeter to area must not exceed 0.02. Do any of the lots meet the criteria?

# %% [markdown]
# ### 3.3) Solve it with a loop.

# %% [markdown]
# #### 3.4) Solve it with a comprehension.
