# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center> Lecture w03-A <br></center></h2>
# <h2><center>Collections</h2>
#
# ---

# %% [markdown]
# # Working with sequence

# %%
aset   = {'zero','one','two','three','four','five','six'}
atuple = ('zero','one','two','three','four','five','six')
alist  = ['zero','one','two','three','four','five','six']
astr = 'abcdefg'

# %% [markdown]
# # Example use of a dictionary
#
# <img src="resources/countries.png" width="600" />

# %%
country_population = {
    'India' : 1428627663,
    'China' : 1425671352,
    'United States' : 339996563,
    'Indonesia' : 277534122,
    'Pakistan' : 240485658
}
